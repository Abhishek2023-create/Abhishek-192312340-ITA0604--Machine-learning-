# %%
import pandas as pd

# Create data
data = {
    "Name": ["Arun", "Bala", "Cathy"],
    "Marks": [80, 65, 90]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display data
print(df)
# Out:
#     Name  Marks
# 0   Arun     80
# 1   Bala     65
# 2  Cathy     90
