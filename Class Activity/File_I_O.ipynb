# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("/content/students.csv")

# Display the data
print("Student Data:")
print(df)

# Save data to CSV
df.to_csv("output.csv", index=False)

# Read Excel file
# df = pd.read_excel("students.xlsx") # This line caused the FileNotFoundError

# Display Excel data
# print("\nExcel Data:")
# print(df)

# Save data to Excel
# df.to_excel("output.xlsx", index=False)
# Out:
# Student Data:
#     Name  Marks        City
# 0   Arun     80     Chennai
# 1   Bala     65     Madurai
# 2  Cathy     90       Salem
# 3  David     75     Chennai
# 4   Esha     88  Coimbatore
